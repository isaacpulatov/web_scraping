# %%
import requests # for making standard html requests
from bs4 import BeautifulSoup # magical tool for parsing html data
import json # for parsing data
import pandas as pd # premier library for data organization

# %%
URL = ('http://www.city-data.com/neighborhood/Upper-West-Side-New-York-NY.html')
page = requests.get(URL)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
page = requests.get(URL)
page.encoding = 'ISO-885901'
soup = BeautifulSoup(page.text, 'html.parser')

# %%
#print(soup.prettify())
#I would run this in Jupyter, but not here

# %%
column_names = ['Street','Length','Direction','Address Min','Address Max']
df = pd.DataFrame(columns = column_names)
df
# Out:
# Empty DataFrame
# Columns: [Street, Length, Direction, Address Min, Address Max]
# Index: []

# %%
df.reindex(df.index.tolist() + list(range(0, 69)))
# Out:
#    Street Length Direction Address Min Address Max
# 0     NaN    NaN       NaN         NaN         NaN
# 1     NaN    NaN       NaN         NaN         NaN
# 2     NaN    NaN       NaN         NaN         NaN
# 3     NaN    NaN       NaN         NaN         NaN
# 4     NaN    NaN       NaN         NaN         NaN
# 5     NaN    NaN       NaN         NaN         NaN
# 6     NaN    NaN       NaN         NaN         NaN
# 7     NaN    NaN       NaN         NaN         NaN
# 8     NaN    NaN       NaN         NaN         NaN
# 9     NaN    NaN       NaN         NaN         NaN
# 10    NaN    NaN       NaN         NaN         NaN
# 11    NaN    NaN       NaN         NaN         NaN
# 12    NaN    NaN       NaN         NaN         NaN
# 13    NaN    NaN       NaN         NaN         NaN
# 14    NaN    NaN       NaN         NaN         NaN
# 15    NaN    NaN       NaN         NaN         NaN
# 16    NaN    NaN       NaN         NaN         NaN
# 17    NaN    NaN       NaN         NaN         NaN
# 18    NaN    NaN       NaN         NaN         NaN
# 19    NaN    NaN       NaN         NaN         NaN
# 20    NaN    NaN       NaN         NaN         NaN
# 21    NaN    NaN       NaN         NaN         NaN
# 22    NaN    NaN       NaN         NaN         NaN
# 23    NaN    NaN       NaN         NaN         NaN
# 24    NaN    NaN       NaN         NaN         NaN
# 25    NaN    NaN       NaN         NaN         NaN
# 26    NaN    NaN       NaN         NaN         NaN
# 27    NaN    NaN       NaN         NaN         NaN
# 28    NaN    NaN       NaN         NaN         NaN
# 29    NaN    NaN       NaN         NaN         NaN
# 30    NaN    NaN       NaN         NaN         NaN
# 31    NaN    NaN       NaN         NaN         NaN
# 32    NaN    NaN       NaN         NaN         NaN
# 33    NaN    NaN       NaN         NaN         NaN
# 34    NaN    NaN       NaN         NaN         NaN
# 35    NaN    NaN       NaN         NaN         NaN
# 36    NaN    NaN       NaN         NaN         NaN
# 37    NaN    NaN       NaN         NaN         NaN
# 38    NaN    NaN       NaN         NaN         NaN
# 39    NaN    NaN       NaN         NaN         NaN
# 40    NaN    NaN       NaN         NaN         NaN
# 41    NaN    NaN       NaN         NaN         NaN
# 42    NaN    NaN       NaN         NaN         NaN
# 43    NaN    NaN       NaN         NaN         NaN
# 44    NaN    NaN       NaN         NaN         NaN
# 45    NaN    NaN       NaN         NaN         NaN
# 46    NaN    NaN       NaN         NaN         NaN
# 47    NaN    NaN       NaN         NaN         NaN
# 48    NaN    NaN       NaN         NaN         NaN
# 49    NaN    NaN       NaN         NaN         NaN
# 50    NaN    NaN       NaN         NaN         NaN
# 51    NaN    NaN       NaN         NaN         NaN
# 52    NaN    NaN       NaN         NaN         NaN
# 53    NaN    NaN       NaN         NaN         NaN
# 54    NaN    NaN       NaN         NaN         NaN
# 55    NaN    NaN       NaN         NaN         NaN
# 56    NaN    NaN       NaN         NaN         NaN
# 57    NaN    NaN       NaN         NaN         NaN
# 58    NaN    NaN       NaN         NaN         NaN
# 59    NaN    NaN       NaN         NaN         NaN
# 60    NaN    NaN       NaN         NaN         NaN
# 61    NaN    NaN       NaN         NaN         NaN
# 62    NaN    NaN       NaN         NaN         NaN
# 63    NaN    NaN       NaN         NaN         NaN
# 64    NaN    NaN       NaN         NaN         NaN
# 65    NaN    NaN       NaN         NaN         NaN
# 66    NaN    NaN       NaN         NaN         NaN
# 67    NaN    NaN       NaN         NaN         NaN
# 68    NaN    NaN       NaN         NaN         NaN

# %%
dollar_tree_list = soup.find_all(class_ = 'col-xs-12 col-sm-6 col-md-4')
for i in dollar_tree_list[:2]:
    print("")
    print(i)
# Out:
# <div class="col-xs-12 col-sm-6 col-md-4"><div class="panel panel-default panel-tile"><div class="panel-heading"><h4 class="panel-title">State Hwy 9a (Henry Hudson Pkwy)
# </h4></div><div class="panel-body"><b>Length:</b> 1.11 miles<br/>
# <b>Directions:</b> N-S, SW-NE
# </div></div></div>
#
# <div class="col-xs-12 col-sm-6 col-md-4"><div class="panel panel-default panel-tile"><div class="panel-heading"><h4 class="panel-title">Riverside Dr
# </h4></div><div class="panel-body"><b>Length:</b> 3.21 miles<br/>
# <b>Directions:</b> E-W, N-S, SW-NE
# </div></div></div>

# %%
for i in dollar_tree_list[67:]:
    print("")
    print(i)
# Out:
# <div class="col-xs-12 col-sm-6 col-md-4"><div class="panel panel-default panel-tile"><div class="panel-heading"><h4 class="panel-title">W 70th St
# </h4></div><div class="panel-body"><b>Length:</b> 0.02 miles<br/>
# <b>Direction:</b> SE-NW
# </div></div></div>
#
# <div class="col-xs-12 col-sm-6 col-md-4"><div class="panel panel-default panel-tile"><div class="panel-heading"><h4 class="panel-title">Metro North Commuter RR (Amtrak RR)
# </h4></div><div class="panel-body"><b>Length:</b> 0.69 miles<br/>
# <b>Directions:</b> N-S, SE-NW, SW-NE
# </div></div></div>

# %%
type(dollar_tree_list)
len(dollar_tree_list)
# Out:
# 69

# %%
i = 0
for table in dollar_tree_list[:]:
    street = table.contents[0].contents[0].contents[0].contents[0]
    #print(street)
    street = street.replace('\r\n', '')
    df.loc[i, 'Street'] = street
    i+=1
df
# Out:
#                                         Street Length Direction Address Min  \
# 0             State Hwy 9a (Henry Hudson Pkwy)    NaN       NaN         NaN
# 1                                 Riverside Dr    NaN       NaN         NaN
# 2                                 Columbus Ave    NaN       NaN         NaN
# 3                                Amsterdam Ave    NaN       NaN         NaN
# 4                               Central Park W    NaN       NaN         NaN
# 5                                     Broadway    NaN       NaN         NaN
# 6                                    W End Ave    NaN       NaN         NaN
# 7                          W 72nd St (W 72 St)    NaN       NaN         NaN
# 8                                      W 71 St    NaN       NaN         NaN
# 9                          W 70th St (W 70 St)    NaN       NaN         NaN
# 10                         W 86th St (W 86 St)    NaN       NaN         NaN
# 11                         W 85 St (W 85th St)    NaN       NaN         NaN
# 12                         W 87 St (W 87th St)    NaN       NaN         NaN
# 13                         W 88th St (W 88 St)    NaN       NaN         NaN
# 14                                    W 100 St    NaN       NaN         NaN
# 15     W 84th St (W 84 St, Edgar Allen Poe St)    NaN       NaN         NaN
# 16                         W 89th St (W 89 St)    NaN       NaN         NaN
# 17                         W 95 St (W 95th St)    NaN       NaN         NaN
# 18                         W 94 St (W 94th St)    NaN       NaN         NaN
# 19                                     W 66 St    NaN       NaN         NaN
# 20                         W 76th St (W 76 St)    NaN       NaN         NaN
# 21                         W 83rd St (W 83 St)    NaN       NaN         NaN
# 22                         W 96 St (W 96th St)    NaN       NaN         NaN
# 23                         W 77 St (W 77th St)    NaN       NaN         NaN
# 24                       W 108th St (W 108 St)    NaN       NaN         NaN
# 25                         W 75 St (W 75th St)    NaN       NaN         NaN
# 26                       W 104 St (W 104th St)    NaN       NaN         NaN
# 27  W 106th St (W 106 St, Duke Ellington Blvd)    NaN       NaN         NaN
# 28                         W 90 St (W 90th St)    NaN       NaN         NaN
# 29                         W 93rd St (W 93 St)    NaN       NaN         NaN
# 30                         W 74th St (W 74 St)    NaN       NaN         NaN
# 31                         W 91st St (W 91 St)    NaN       NaN         NaN
# 32                       W 109 St (W 109th St)    NaN       NaN         NaN
# 33                       W 107th St (W 107 St)    NaN       NaN         NaN
# 34                       W 105 St (W 105th St)    NaN       NaN         NaN
# 35                         W 92nd St (W 92 St)    NaN       NaN         NaN
# 36                                   W 60th St    NaN       NaN         NaN
# 37                         W 82 St (W 82nd St)    NaN       NaN         NaN
# 38                                   W 97th St    NaN       NaN         NaN
# 39                         W 73rd St (W 73 St)    NaN       NaN         NaN
# 40                         W 81st St (W 81 St)    NaN       NaN         NaN
# 41                         W 65th St (W 65 St)    NaN       NaN         NaN
# 42                         W 78th St (W 78 St)    NaN       NaN         NaN
# 43                               Manhattan Ave    NaN       NaN         NaN
# 44                         W 79th St (W 79 St)    NaN       NaN         NaN
# 45                       W 102nd St (W 102 St)    NaN       NaN         NaN
# 46                         W 80th St (W 80 St)    NaN       NaN         NaN
# 47                         W 62 St (W 62nd St)    NaN       NaN         NaN
# 48                       W 103rd St (W 103 St)    NaN       NaN         NaN
# 49                                     W 69 St    NaN       NaN         NaN
# 50                                     W 68 St    NaN       NaN         NaN
# 51                         W 61st St (W 61 St)    NaN       NaN         NaN
# 52                                     W 67 St    NaN       NaN         NaN
# 53                       W 101st St (W 101 St)    NaN       NaN         NaN
# 54                         W 64th St (W 64 St)    NaN       NaN         NaN
# 55                                   W 59th St    NaN       NaN         NaN
# 56                              Riverside Blvd    NaN       NaN         NaN
# 57     W 63rd St (Thelonius Monk Cir, W 63 St)    NaN       NaN         NaN
# 58                         W 99 St (W 99th St)    NaN       NaN         NaN
# 59                         W 98 St (W 98th St)    NaN       NaN         NaN
# 60                                  Freedom Pl    NaN       NaN         NaN
# 61                       W 61 Dr (W 61st Dr, )    NaN       NaN         NaN
# 62                                   W 79th St    NaN       NaN         NaN
# 63                                   W 64th St    NaN       NaN         NaN
# 64                               Pomander Walk    NaN       NaN         NaN
# 65                                  E Tower Dr    NaN       NaN         NaN
# 66                                   W 63rd St    NaN       NaN         NaN
# 67                                   W 70th St    NaN       NaN         NaN
# 68         Metro North Commuter RR (Amtrak RR)    NaN       NaN         NaN
#
#    Address Max
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53         NaN
# 54         NaN
# 55         NaN
# 56         NaN
# 57         NaN
# 58         NaN
# 59         NaN
# 60         NaN
# 61         NaN
# 62         NaN
# 63         NaN
# 64         NaN
# 65         NaN
# 66         NaN
# 67         NaN
# 68         NaN

# %%
i = 0
for table in dollar_tree_list[:]:
    miles = (table.contents[0].contents[1].contents[1])
    miles = miles.replace(' miles', '')
    miles = miles.strip()
    miles = float(miles)
    df.loc[i, 'Length'] = miles
    i+=1
df
# Out:
#                                         Street Length Direction Address Min  \
# 0             State Hwy 9a (Henry Hudson Pkwy)   1.11       NaN         NaN
# 1                                 Riverside Dr   3.21       NaN         NaN
# 2                                 Columbus Ave   2.73       NaN         NaN
# 3                                Amsterdam Ave   2.73       NaN         NaN
# 4                               Central Park W   2.72       NaN         NaN
# 5                                     Broadway   2.71       NaN         NaN
# 6                                    W End Ave   2.67       NaN         NaN
# 7                          W 72nd St (W 72 St)   0.84       NaN         NaN
# 8                                      W 71 St   0.83       NaN         NaN
# 9                          W 70th St (W 70 St)   0.83       NaN         NaN
# 10                         W 86th St (W 86 St)   0.82       NaN         NaN
# 11                         W 85 St (W 85th St)   0.82       NaN         NaN
# 12                         W 87 St (W 87th St)   0.82       NaN         NaN
# 13                         W 88th St (W 88 St)   0.82       NaN         NaN
# 14                                    W 100 St   0.81       NaN         NaN
# 15     W 84th St (W 84 St, Edgar Allen Poe St)    0.8       NaN         NaN
# 16                         W 89th St (W 89 St)    0.8       NaN         NaN
# 17                         W 95 St (W 95th St)    0.8       NaN         NaN
# 18                         W 94 St (W 94th St)   0.79       NaN         NaN
# 19                                     W 66 St   0.78       NaN         NaN
# 20                         W 76th St (W 76 St)   0.78       NaN         NaN
# 21                         W 83rd St (W 83 St)   0.78       NaN         NaN
# 22                         W 96 St (W 96th St)   0.77       NaN         NaN
# 23                         W 77 St (W 77th St)   0.77       NaN         NaN
# 24                       W 108th St (W 108 St)   0.77       NaN         NaN
# 25                         W 75 St (W 75th St)   0.77       NaN         NaN
# 26                       W 104 St (W 104th St)   0.77       NaN         NaN
# 27  W 106th St (W 106 St, Duke Ellington Blvd)   0.77       NaN         NaN
# 28                         W 90 St (W 90th St)   0.77       NaN         NaN
# 29                         W 93rd St (W 93 St)   0.76       NaN         NaN
# 30                         W 74th St (W 74 St)   0.76       NaN         NaN
# 31                         W 91st St (W 91 St)   0.75       NaN         NaN
# 32                       W 109 St (W 109th St)   0.75       NaN         NaN
# 33                       W 107th St (W 107 St)   0.75       NaN         NaN
# 34                       W 105 St (W 105th St)   0.75       NaN         NaN
# 35                         W 92nd St (W 92 St)   0.75       NaN         NaN
# 36                                   W 60th St   0.75       NaN         NaN
# 37                         W 82 St (W 82nd St)   0.75       NaN         NaN
# 38                                   W 97th St   0.75       NaN         NaN
# 39                         W 73rd St (W 73 St)   0.74       NaN         NaN
# 40                         W 81st St (W 81 St)   0.73       NaN         NaN
# 41                         W 65th St (W 65 St)   0.64       NaN         NaN
# 42                         W 78th St (W 78 St)   0.55       NaN         NaN
# 43                               Manhattan Ave   0.54       NaN         NaN
# 44                         W 79th St (W 79 St)   0.53       NaN         NaN
# 45                       W 102nd St (W 102 St)   0.53       NaN         NaN
# 46                         W 80th St (W 80 St)   0.53       NaN         NaN
# 47                         W 62 St (W 62nd St)   0.52       NaN         NaN
# 48                       W 103rd St (W 103 St)   0.51       NaN         NaN
# 49                                     W 69 St    0.5       NaN         NaN
# 50                                     W 68 St   0.49       NaN         NaN
# 51                         W 61st St (W 61 St)   0.49       NaN         NaN
# 52                                     W 67 St   0.46       NaN         NaN
# 53                       W 101st St (W 101 St)   0.44       NaN         NaN
# 54                         W 64th St (W 64 St)   0.43       NaN         NaN
# 55                                   W 59th St   0.43       NaN         NaN
# 56                              Riverside Blvd    0.4       NaN         NaN
# 57     W 63rd St (Thelonius Monk Cir, W 63 St)   0.38       NaN         NaN
# 58                         W 99 St (W 99th St)   0.34       NaN         NaN
# 59                         W 98 St (W 98th St)   0.32       NaN         NaN
# 60                                  Freedom Pl    0.2       NaN         NaN
# 61                       W 61 Dr (W 61st Dr, )   0.09       NaN         NaN
# 62                                   W 79th St   0.07       NaN         NaN
# 63                                   W 64th St   0.06       NaN         NaN
# 64                               Pomander Walk   0.05       NaN         NaN
# 65                                  E Tower Dr   0.05       NaN         NaN
# 66                                   W 63rd St   0.04       NaN         NaN
# 67                                   W 70th St   0.02       NaN         NaN
# 68         Metro North Commuter RR (Amtrak RR)   0.69       NaN         NaN
#
#    Address Max
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53         NaN
# 54         NaN
# 55         NaN
# 56         NaN
# 57         NaN
# 58         NaN
# 59         NaN
# 60         NaN
# 61         NaN
# 62         NaN
# 63         NaN
# 64         NaN
# 65         NaN
# 66         NaN
# 67         NaN
# 68         NaN

# %%
df = df.rename(columns={'Length': 'Miles'})

# %%
i = 0
for table in dollar_tree_list[:]:
    string = (table.contents[0].contents[1].contents[5])
    string = string.replace('\r\n', '')
    string = string.strip()
    df.loc[i, 'Direction'] = string
    i+=1
df
# Out:
#                                         Street Miles          Direction  \
# 0             State Hwy 9a (Henry Hudson Pkwy)  1.11         N-S, SW-NE
# 1                                 Riverside Dr  3.21    E-W, N-S, SW-NE
# 2                                 Columbus Ave  2.73              SW-NE
# 3                                Amsterdam Ave  2.73              SW-NE
# 4                               Central Park W  2.72              SW-NE
# 5                                     Broadway  2.71         N-S, SW-NE
# 6                                    W End Ave  2.67              SW-NE
# 7                          W 72nd St (W 72 St)  0.84         E-W, SE-NW
# 8                                      W 71 St  0.83         E-W, SE-NW
# 9                          W 70th St (W 70 St)  0.83         E-W, SE-NW
# 10                         W 86th St (W 86 St)  0.82         E-W, SE-NW
# 11                         W 85 St (W 85th St)  0.82              SE-NW
# 12                         W 87 St (W 87th St)  0.82              SE-NW
# 13                         W 88th St (W 88 St)  0.82              SE-NW
# 14                                    W 100 St  0.81         E-W, SE-NW
# 15     W 84th St (W 84 St, Edgar Allen Poe St)   0.8              SE-NW
# 16                         W 89th St (W 89 St)   0.8              SE-NW
# 17                         W 95 St (W 95th St)   0.8              SE-NW
# 18                         W 94 St (W 94th St)  0.79              SE-NW
# 19                                     W 66 St  0.78              SE-NW
# 20                         W 76th St (W 76 St)  0.78              SE-NW
# 21                         W 83rd St (W 83 St)  0.78         E-W, SE-NW
# 22                         W 96 St (W 96th St)  0.77              SE-NW
# 23                         W 77 St (W 77th St)  0.77         E-W, SE-NW
# 24                       W 108th St (W 108 St)  0.77         E-W, SE-NW
# 25                         W 75 St (W 75th St)  0.77              SE-NW
# 26                       W 104 St (W 104th St)  0.77         E-W, SE-NW
# 27  W 106th St (W 106 St, Duke Ellington Blvd)  0.77         E-W, SE-NW
# 28                         W 90 St (W 90th St)  0.77              SE-NW
# 29                         W 93rd St (W 93 St)  0.76              SE-NW
# 30                         W 74th St (W 74 St)  0.76              SE-NW
# 31                         W 91st St (W 91 St)  0.75              SE-NW
# 32                       W 109 St (W 109th St)  0.75              SE-NW
# 33                       W 107th St (W 107 St)  0.75         E-W, SE-NW
# 34                       W 105 St (W 105th St)  0.75              SE-NW
# 35                         W 92nd St (W 92 St)  0.75              SE-NW
# 36                                   W 60th St  0.75         E-W, SE-NW
# 37                         W 82 St (W 82nd St)  0.75              SE-NW
# 38                                   W 97th St  0.75         E-W, SE-NW
# 39                         W 73rd St (W 73 St)  0.74              SE-NW
# 40                         W 81st St (W 81 St)  0.73              SE-NW
# 41                         W 65th St (W 65 St)  0.64         E-W, SE-NW
# 42                         W 78th St (W 78 St)  0.55              SE-NW
# 43                               Manhattan Ave  0.54              SW-NE
# 44                         W 79th St (W 79 St)  0.53              SE-NW
# 45                       W 102nd St (W 102 St)  0.53         E-W, SE-NW
# 46                         W 80th St (W 80 St)  0.53              SE-NW
# 47                         W 62 St (W 62nd St)  0.52         E-W, SE-NW
# 48                       W 103rd St (W 103 St)  0.51         E-W, SE-NW
# 49                                     W 69 St   0.5         E-W, SE-NW
# 50                                     W 68 St  0.49         E-W, SE-NW
# 51                         W 61st St (W 61 St)  0.49              SE-NW
# 52                                     W 67 St  0.46         E-W, SE-NW
# 53                       W 101st St (W 101 St)  0.44              SE-NW
# 54                         W 64th St (W 64 St)  0.43         E-W, SE-NW
# 55                                   W 59th St  0.43              SE-NW
# 56                              Riverside Blvd   0.4    E-W, N-S, SW-NE
# 57     W 63rd St (Thelonius Monk Cir, W 63 St)  0.38              SE-NW
# 58                         W 99 St (W 99th St)  0.34              SE-NW
# 59                         W 98 St (W 98th St)  0.32              SE-NW
# 60                                  Freedom Pl   0.2              SW-NE
# 61                       W 61 Dr (W 61st Dr, )  0.09              SE-NW
# 62                                   W 79th St  0.07         E-W, SE-NW
# 63                                   W 64th St  0.06              SE-NW
# 64                               Pomander Walk  0.05              SW-NE
# 65                                  E Tower Dr  0.05              SW-NE
# 66                                   W 63rd St  0.04              SE-NW
# 67                                   W 70th St  0.02              SE-NW
# 68         Metro North Commuter RR (Amtrak RR)  0.69  N-S, SE-NW, SW-NE
#
#    Address Min Address Max
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 22         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN
# 28         NaN         NaN
# 29         NaN         NaN
# 30         NaN         NaN
# 31         NaN         NaN
# 32         NaN         NaN
# 33         NaN         NaN
# 34         NaN         NaN
# 35         NaN         NaN
# 36         NaN         NaN
# 37         NaN         NaN
# 38         NaN         NaN
# 39         NaN         NaN
# 40         NaN         NaN
# 41         NaN         NaN
# 42         NaN         NaN
# 43         NaN         NaN
# 44         NaN         NaN
# 45         NaN         NaN
# 46         NaN         NaN
# 47         NaN         NaN
# 48         NaN         NaN
# 49         NaN         NaN
# 50         NaN         NaN
# 51         NaN         NaN
# 52         NaN         NaN
# 53         NaN         NaN
# 54         NaN         NaN
# 55         NaN         NaN
# 56         NaN         NaN
# 57         NaN         NaN
# 58         NaN         NaN
# 59         NaN         NaN
# 60         NaN         NaN
# 61         NaN         NaN
# 62         NaN         NaN
# 63         NaN         NaN
# 64         NaN         NaN
# 65         NaN         NaN
# 66         NaN         NaN
# 67         NaN         NaN
# 68         NaN         NaN

# %%
i = 0
for table in dollar_tree_list[:]:
    if 'Address range' in (str(table.contents[0].contents[1])):
        string = table.contents[0].contents[1].contents[8]
        string = string.strip()
        integer = int(string)
        df.loc[i, 'Address Min'] = integer
    i+=1
df
# Out:
#                                         Street Miles          Direction  \
# 0             State Hwy 9a (Henry Hudson Pkwy)  1.11         N-S, SW-NE
# 1                                 Riverside Dr  3.21    E-W, N-S, SW-NE
# 2                                 Columbus Ave  2.73              SW-NE
# 3                                Amsterdam Ave  2.73              SW-NE
# 4                               Central Park W  2.72              SW-NE
# 5                                     Broadway  2.71         N-S, SW-NE
# 6                                    W End Ave  2.67              SW-NE
# 7                          W 72nd St (W 72 St)  0.84         E-W, SE-NW
# 8                                      W 71 St  0.83         E-W, SE-NW
# 9                          W 70th St (W 70 St)  0.83         E-W, SE-NW
# 10                         W 86th St (W 86 St)  0.82         E-W, SE-NW
# 11                         W 85 St (W 85th St)  0.82              SE-NW
# 12                         W 87 St (W 87th St)  0.82              SE-NW
# 13                         W 88th St (W 88 St)  0.82              SE-NW
# 14                                    W 100 St  0.81         E-W, SE-NW
# 15     W 84th St (W 84 St, Edgar Allen Poe St)   0.8              SE-NW
# 16                         W 89th St (W 89 St)   0.8              SE-NW
# 17                         W 95 St (W 95th St)   0.8              SE-NW
# 18                         W 94 St (W 94th St)  0.79              SE-NW
# 19                                     W 66 St  0.78              SE-NW
# 20                         W 76th St (W 76 St)  0.78              SE-NW
# 21                         W 83rd St (W 83 St)  0.78         E-W, SE-NW
# 22                         W 96 St (W 96th St)  0.77              SE-NW
# 23                         W 77 St (W 77th St)  0.77         E-W, SE-NW
# 24                       W 108th St (W 108 St)  0.77         E-W, SE-NW
# 25                         W 75 St (W 75th St)  0.77              SE-NW
# 26                       W 104 St (W 104th St)  0.77         E-W, SE-NW
# 27  W 106th St (W 106 St, Duke Ellington Blvd)  0.77         E-W, SE-NW
# 28                         W 90 St (W 90th St)  0.77              SE-NW
# 29                         W 93rd St (W 93 St)  0.76              SE-NW
# 30                         W 74th St (W 74 St)  0.76              SE-NW
# 31                         W 91st St (W 91 St)  0.75              SE-NW
# 32                       W 109 St (W 109th St)  0.75              SE-NW
# 33                       W 107th St (W 107 St)  0.75         E-W, SE-NW
# 34                       W 105 St (W 105th St)  0.75              SE-NW
# 35                         W 92nd St (W 92 St)  0.75              SE-NW
# 36                                   W 60th St  0.75         E-W, SE-NW
# 37                         W 82 St (W 82nd St)  0.75              SE-NW
# 38                                   W 97th St  0.75         E-W, SE-NW
# 39                         W 73rd St (W 73 St)  0.74              SE-NW
# 40                         W 81st St (W 81 St)  0.73              SE-NW
# 41                         W 65th St (W 65 St)  0.64         E-W, SE-NW
# 42                         W 78th St (W 78 St)  0.55              SE-NW
# 43                               Manhattan Ave  0.54              SW-NE
# 44                         W 79th St (W 79 St)  0.53              SE-NW
# 45                       W 102nd St (W 102 St)  0.53         E-W, SE-NW
# 46                         W 80th St (W 80 St)  0.53              SE-NW
# 47                         W 62 St (W 62nd St)  0.52         E-W, SE-NW
# 48                       W 103rd St (W 103 St)  0.51         E-W, SE-NW
# 49                                     W 69 St   0.5         E-W, SE-NW
# 50                                     W 68 St  0.49         E-W, SE-NW
# 51                         W 61st St (W 61 St)  0.49              SE-NW
# 52                                     W 67 St  0.46         E-W, SE-NW
# 53                       W 101st St (W 101 St)  0.44              SE-NW
# 54                         W 64th St (W 64 St)  0.43         E-W, SE-NW
# 55                                   W 59th St  0.43              SE-NW
# 56                              Riverside Blvd   0.4    E-W, N-S, SW-NE
# 57     W 63rd St (Thelonius Monk Cir, W 63 St)  0.38              SE-NW
# 58                         W 99 St (W 99th St)  0.34              SE-NW
# 59                         W 98 St (W 98th St)  0.32              SE-NW
# 60                                  Freedom Pl   0.2              SW-NE
# 61                       W 61 Dr (W 61st Dr, )  0.09              SE-NW
# 62                                   W 79th St  0.07         E-W, SE-NW
# 63                                   W 64th St  0.06              SE-NW
# 64                               Pomander Walk  0.05              SW-NE
# 65                                  E Tower Dr  0.05              SW-NE
# 66                                   W 63rd St  0.04              SE-NW
# 67                                   W 70th St  0.02              SE-NW
# 68         Metro North Commuter RR (Amtrak RR)  0.69  N-S, SE-NW, SW-NE
#
#    Address Min Address Max
# 0          NaN         NaN
# 1          NaN         NaN
# 2            1         NaN
# 3            1         NaN
# 4            1         NaN
# 5         1835         NaN
# 6            1         NaN
# 7            2         NaN
# 8            1         NaN
# 9            1         NaN
# 10           7         NaN
# 11           1         NaN
# 12           2         NaN
# 13           1         NaN
# 14           1         NaN
# 15           1         NaN
# 16           1         NaN
# 17           1         NaN
# 18           1         NaN
# 19           1         NaN
# 20           1         NaN
# 21           1         NaN
# 22           1         NaN
# 23           1         NaN
# 24           1         NaN
# 25           1         NaN
# 26           1         NaN
# 27           1         NaN
# 28           1         NaN
# 29           1         NaN
# 30           1         NaN
# 31           1         NaN
# 32           1         NaN
# 33           1         NaN
# 34           1         NaN
# 35           1         NaN
# 36           1         NaN
# 37           1         NaN
# 38           1         NaN
# 39           1         NaN
# 40           1         NaN
# 41           1         NaN
# 42         100         NaN
# 43           1         NaN
# 44           1         NaN
# 45           1         NaN
# 46         100         NaN
# 47           1         NaN
# 48           1         NaN
# 49           1         NaN
# 50           1         NaN
# 51           1         NaN
# 52           1         NaN
# 53           1         NaN
# 54           1         NaN
# 55         300         NaN
# 56         NaN         NaN
# 57           1         NaN
# 58         200         NaN
# 59         200         NaN
# 60           1         NaN
# 61         NaN         NaN
# 62         NaN         NaN
# 63         NaN         NaN
# 64           1         NaN
# 65         NaN         NaN
# 66         NaN         NaN
# 67         NaN         NaN
# 68         NaN         NaN

# %%
i = 0
for table in dollar_tree_list[:]:
    if 'Address range' in (str(table.contents[0].contents[1])):
        string = table.contents[0].contents[1].contents[10]
        string = string.replace('\r\n', '')
        string = string.strip()
        integer = int(string)
        df.loc[i, 'Address Max'] = integer
    i+=1
df
# Out:
#                                         Street Miles          Direction  \
# 0             State Hwy 9a (Henry Hudson Pkwy)  1.11         N-S, SW-NE
# 1                                 Riverside Dr  3.21    E-W, N-S, SW-NE
# 2                                 Columbus Ave  2.73              SW-NE
# 3                                Amsterdam Ave  2.73              SW-NE
# 4                               Central Park W  2.72              SW-NE
# 5                                     Broadway  2.71         N-S, SW-NE
# 6                                    W End Ave  2.67              SW-NE
# 7                          W 72nd St (W 72 St)  0.84         E-W, SE-NW
# 8                                      W 71 St  0.83         E-W, SE-NW
# 9                          W 70th St (W 70 St)  0.83         E-W, SE-NW
# 10                         W 86th St (W 86 St)  0.82         E-W, SE-NW
# 11                         W 85 St (W 85th St)  0.82              SE-NW
# 12                         W 87 St (W 87th St)  0.82              SE-NW
# 13                         W 88th St (W 88 St)  0.82              SE-NW
# 14                                    W 100 St  0.81         E-W, SE-NW
# 15     W 84th St (W 84 St, Edgar Allen Poe St)   0.8              SE-NW
# 16                         W 89th St (W 89 St)   0.8              SE-NW
# 17                         W 95 St (W 95th St)   0.8              SE-NW
# 18                         W 94 St (W 94th St)  0.79              SE-NW
# 19                                     W 66 St  0.78              SE-NW
# 20                         W 76th St (W 76 St)  0.78              SE-NW
# 21                         W 83rd St (W 83 St)  0.78         E-W, SE-NW
# 22                         W 96 St (W 96th St)  0.77              SE-NW
# 23                         W 77 St (W 77th St)  0.77         E-W, SE-NW
# 24                       W 108th St (W 108 St)  0.77         E-W, SE-NW
# 25                         W 75 St (W 75th St)  0.77              SE-NW
# 26                       W 104 St (W 104th St)  0.77         E-W, SE-NW
# 27  W 106th St (W 106 St, Duke Ellington Blvd)  0.77         E-W, SE-NW
# 28                         W 90 St (W 90th St)  0.77              SE-NW
# 29                         W 93rd St (W 93 St)  0.76              SE-NW
# 30                         W 74th St (W 74 St)  0.76              SE-NW
# 31                         W 91st St (W 91 St)  0.75              SE-NW
# 32                       W 109 St (W 109th St)  0.75              SE-NW
# 33                       W 107th St (W 107 St)  0.75         E-W, SE-NW
# 34                       W 105 St (W 105th St)  0.75              SE-NW
# 35                         W 92nd St (W 92 St)  0.75              SE-NW
# 36                                   W 60th St  0.75         E-W, SE-NW
# 37                         W 82 St (W 82nd St)  0.75              SE-NW
# 38                                   W 97th St  0.75         E-W, SE-NW
# 39                         W 73rd St (W 73 St)  0.74              SE-NW
# 40                         W 81st St (W 81 St)  0.73              SE-NW
# 41                         W 65th St (W 65 St)  0.64         E-W, SE-NW
# 42                         W 78th St (W 78 St)  0.55              SE-NW
# 43                               Manhattan Ave  0.54              SW-NE
# 44                         W 79th St (W 79 St)  0.53              SE-NW
# 45                       W 102nd St (W 102 St)  0.53         E-W, SE-NW
# 46                         W 80th St (W 80 St)  0.53              SE-NW
# 47                         W 62 St (W 62nd St)  0.52         E-W, SE-NW
# 48                       W 103rd St (W 103 St)  0.51         E-W, SE-NW
# 49                                     W 69 St   0.5         E-W, SE-NW
# 50                                     W 68 St  0.49         E-W, SE-NW
# 51                         W 61st St (W 61 St)  0.49              SE-NW
# 52                                     W 67 St  0.46         E-W, SE-NW
# 53                       W 101st St (W 101 St)  0.44              SE-NW
# 54                         W 64th St (W 64 St)  0.43         E-W, SE-NW
# 55                                   W 59th St  0.43              SE-NW
# 56                              Riverside Blvd   0.4    E-W, N-S, SW-NE
# 57     W 63rd St (Thelonius Monk Cir, W 63 St)  0.38              SE-NW
# 58                         W 99 St (W 99th St)  0.34              SE-NW
# 59                         W 98 St (W 98th St)  0.32              SE-NW
# 60                                  Freedom Pl   0.2              SW-NE
# 61                       W 61 Dr (W 61st Dr, )  0.09              SE-NW
# 62                                   W 79th St  0.07         E-W, SE-NW
# 63                                   W 64th St  0.06              SE-NW
# 64                               Pomander Walk  0.05              SW-NE
# 65                                  E Tower Dr  0.05              SW-NE
# 66                                   W 63rd St  0.04              SE-NW
# 67                                   W 70th St  0.02              SE-NW
# 68         Metro North Commuter RR (Amtrak RR)  0.69  N-S, SE-NW, SW-NE
#
#    Address Min Address Max
# 0          NaN         NaN
# 1          NaN         NaN
# 2            1         997
# 3            1         999
# 4            1         498
# 5         1835        2799
# 6            1         999
# 7            2         399
# 8            1         399
# 9            1         499
# 10           7        3445
# 11           1         399
# 12           2         399
# 13           1         399
# 14           1         399
# 15           1         399
# 16           1         399
# 17           1         399
# 18           1         399
# 19           1         499
# 20           1         399
# 21           1         399
# 22           1         399
# 23           1         399
# 24           1         399
# 25           1         399
# 26           1         399
# 27           1         399
# 28           1         399
# 29           1         399
# 30           1         399
# 31           1         399
# 32           1        1224
# 33           1         399
# 34           1         399
# 35           1         399
# 36           1         299
# 37           1         399
# 38           1         399
# 39           1         399
# 40           1         399
# 41           1         299
# 42         100         399
# 43           1         235
# 44           1         399
# 45           1         399
# 46         100         399
# 47           1         258
# 48           1         399
# 49           1         499
# 50           1         199
# 51           1         299
# 52           1         199
# 53           1         399
# 54           1         299
# 55         300         599
# 56         NaN         NaN
# 57           1         299
# 58         200         399
# 59         200         399
# 60           1         179
# 61         NaN         NaN
# 62         NaN         NaN
# 63         NaN         NaN
# 64           1          24
# 65         NaN         NaN
# 66         NaN         NaN
# 67         NaN         NaN
# 68         NaN         NaN

# %%
df.to_excel(('/Users/Isaac/Desktop/UWS.xlsx'))

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df.head(70)
# Out:
#                                         Street Miles          Direction  \
# 0             State Hwy 9a (Henry Hudson Pkwy)  1.11         N-S, SW-NE
# 1                                 Riverside Dr  3.21    E-W, N-S, SW-NE
# 2                                 Columbus Ave  2.73              SW-NE
# 3                                Amsterdam Ave  2.73              SW-NE
# 4                               Central Park W  2.72              SW-NE
# 5                                     Broadway  2.71         N-S, SW-NE
# 6                                    W End Ave  2.67              SW-NE
# 7                          W 72nd St (W 72 St)  0.84         E-W, SE-NW
# 8                                      W 71 St  0.83         E-W, SE-NW
# 9                          W 70th St (W 70 St)  0.83         E-W, SE-NW
# 10                         W 86th St (W 86 St)  0.82         E-W, SE-NW
# 11                         W 85 St (W 85th St)  0.82              SE-NW
# 12                         W 87 St (W 87th St)  0.82              SE-NW
# 13                         W 88th St (W 88 St)  0.82              SE-NW
# 14                                    W 100 St  0.81         E-W, SE-NW
# 15     W 84th St (W 84 St, Edgar Allen Poe St)   0.8              SE-NW
# 16                         W 89th St (W 89 St)   0.8              SE-NW
# 17                         W 95 St (W 95th St)   0.8              SE-NW
# 18                         W 94 St (W 94th St)  0.79              SE-NW
# 19                                     W 66 St  0.78              SE-NW
# 20                         W 76th St (W 76 St)  0.78              SE-NW
# 21                         W 83rd St (W 83 St)  0.78         E-W, SE-NW
# 22                         W 96 St (W 96th St)  0.77              SE-NW
# 23                         W 77 St (W 77th St)  0.77         E-W, SE-NW
# 24                       W 108th St (W 108 St)  0.77         E-W, SE-NW
# 25                         W 75 St (W 75th St)  0.77              SE-NW
# 26                       W 104 St (W 104th St)  0.77         E-W, SE-NW
# 27  W 106th St (W 106 St, Duke Ellington Blvd)  0.77         E-W, SE-NW
# 28                         W 90 St (W 90th St)  0.77              SE-NW
# 29                         W 93rd St (W 93 St)  0.76              SE-NW
# 30                         W 74th St (W 74 St)  0.76              SE-NW
# 31                         W 91st St (W 91 St)  0.75              SE-NW
# 32                       W 109 St (W 109th St)  0.75              SE-NW
# 33                       W 107th St (W 107 St)  0.75         E-W, SE-NW
# 34                       W 105 St (W 105th St)  0.75              SE-NW
# 35                         W 92nd St (W 92 St)  0.75              SE-NW
# 36                                   W 60th St  0.75         E-W, SE-NW
# 37                         W 82 St (W 82nd St)  0.75              SE-NW
# 38                                   W 97th St  0.75         E-W, SE-NW
# 39                         W 73rd St (W 73 St)  0.74              SE-NW
# 40                         W 81st St (W 81 St)  0.73              SE-NW
# 41                         W 65th St (W 65 St)  0.64         E-W, SE-NW
# 42                         W 78th St (W 78 St)  0.55              SE-NW
# 43                               Manhattan Ave  0.54              SW-NE
# 44                         W 79th St (W 79 St)  0.53              SE-NW
# 45                       W 102nd St (W 102 St)  0.53         E-W, SE-NW
# 46                         W 80th St (W 80 St)  0.53              SE-NW
# 47                         W 62 St (W 62nd St)  0.52         E-W, SE-NW
# 48                       W 103rd St (W 103 St)  0.51         E-W, SE-NW
# 49                                     W 69 St   0.5         E-W, SE-NW
# 50                                     W 68 St  0.49         E-W, SE-NW
# 51                         W 61st St (W 61 St)  0.49              SE-NW
# 52                                     W 67 St  0.46         E-W, SE-NW
# 53                       W 101st St (W 101 St)  0.44              SE-NW
# 54                         W 64th St (W 64 St)  0.43         E-W, SE-NW
# 55                                   W 59th St  0.43              SE-NW
# 56                              Riverside Blvd   0.4    E-W, N-S, SW-NE
# 57     W 63rd St (Thelonius Monk Cir, W 63 St)  0.38              SE-NW
# 58                         W 99 St (W 99th St)  0.34              SE-NW
# 59                         W 98 St (W 98th St)  0.32              SE-NW
# 60                                  Freedom Pl   0.2              SW-NE
# 61                       W 61 Dr (W 61st Dr, )  0.09              SE-NW
# 62                                   W 79th St  0.07         E-W, SE-NW
# 63                                   W 64th St  0.06              SE-NW
# 64                               Pomander Walk  0.05              SW-NE
# 65                                  E Tower Dr  0.05              SW-NE
# 66                                   W 63rd St  0.04              SE-NW
# 67                                   W 70th St  0.02              SE-NW
# 68         Metro North Commuter RR (Amtrak RR)  0.69  N-S, SE-NW, SW-NE
#
#    Address Min Address Max
# 0          NaN         NaN
# 1          NaN         NaN
# 2            1         997
# 3            1         999
# 4            1         498
# 5         1835        2799
# 6            1         999
# 7            2         399
# 8            1         399
# 9            1         499
# 10           7        3445
# 11           1         399
# 12           2         399
# 13           1         399
# 14           1         399
# 15           1         399
# 16           1         399
# 17           1         399
# 18           1         399
# 19           1         499
# 20           1         399
# 21           1         399
# 22           1         399
# 23           1         399
# 24           1         399
# 25           1         399
# 26           1         399
# 27           1         399
# 28           1         399
# 29           1         399
# 30           1         399
# 31           1         399
# 32           1        1224
# 33           1         399
# 34           1         399
# 35           1         399
# 36           1         299
# 37           1         399
# 38           1         399
# 39           1         399
# 40           1         399
# 41           1         299
# 42         100         399
# 43           1         235
# 44           1         399
# 45           1         399
# 46         100         399
# 47           1         258
# 48           1         399
# 49           1         499
# 50           1         199
# 51           1         299
# 52           1         199
# 53           1         399
# 54           1         299
# 55         300         599
# 56         NaN         NaN
# 57           1         299
# 58         200         399
# 59         200         399
# 60           1         179
# 61         NaN         NaN
# 62         NaN         NaN
# 63         NaN         NaN
# 64           1          24
# 65         NaN         NaN
# 66         NaN         NaN
# 67         NaN         NaN
# 68         NaN         NaN
